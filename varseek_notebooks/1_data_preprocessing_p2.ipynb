# %%
import os
import subprocess

import pandas as pd
import scanpy as sc
import anndata as ad
import celltypist
from celltypist import models

import tifffile
import matplotlib.pyplot as plt
import numpy as np
import zarr
import cv2
from scipy import sparse
from IPython.display import Image, display
import tarfile

import sys
sys.path.append(os.path.dirname(os.path.abspath("")))
from utils.utils import set_seed, determine_image_scale_factor, plot_downsampled, save_avg_expression
# set_seed(42)

# %% [markdown]
# Dataset:
#
# - Manuscript: https://www.nature.com/articles/s41588-025-02193-3#data-availability
# - 10x: https://www.10xgenomics.com/platforms/visium/product-family/dataset-human-crc
# - 10x (alt): https://www.10xgenomics.com/datasets/visium-hd-cytassist-gene-expression-libraries-of-human-crc
# - GEO: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE280318
# - SRA: https://www.ncbi.nlm.nih.gov/Traces/study/?acc=PRJNA1177833&f=librarysource_s%3An%3Atranscriptomic%2520single%2520cell%3Blibrary_type_sam_s_dpl277_s%3An%3Agene%2520expression%3Ac&o=library_name_s%3Aa&s=SRR31116645,SRR31116649,SRR31116653,SRR31116657,SRR31116661,SRR31116665,SRR31116669,SRR31116673,SRR31116646,SRR31116650,SRR31116654,SRR31116658,SRR31116662,SRR31116666,SRR31116670,SRR31116674"

# %%
patient_id = 2  # 1, 2, or 5
gpu_id = 0
n_processes = 16
avg_exp_source = "cell_atlas"  # None, "cell_atlas", or "data"
use_shortened_sra_accessions = True
downsample_factor = 8  # for visualization only
patient_id_to_xenium_slice = {1: 7, 2: 6, 5: 7}

# %%
if patient_id not in [1, 2, 5]:
    raise ValueError("patient_id must be 1, 2, or 5")

code_dir = os.path.join(os.path.dirname(os.getcwd()), "data_processing")
data_dir = os.path.join(os.path.dirname(os.getcwd()), "data_varseek")
dir_output = os.path.join(data_dir, f"output_p{patient_id}")

xenium_output_data_dir = os.path.join(data_dir, f"Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs")
he_dir = os.path.join(xenium_output_data_dir, "he_data")
sequencing_data_raw_dir = os.path.join(data_dir, "sequencing_data_raw")
vk_ref_dir = os.path.join(data_dir, "vk_ref_out")
vk_count_dir = os.path.join(dir_output, "vk_count_out_cosmic_cmc_k41")  #!!! change this for each run

for dir_path in [data_dir, xenium_output_data_dir, he_dir, sequencing_data_raw_dir, vk_ref_dir, vk_count_dir]:  # cell_feature_matrix_dir will be created by data download
    os.makedirs(dir_path, exist_ok=True)

nucleus_boundaries_path = os.path.join(xenium_output_data_dir, "nucleus_boundaries.csv.gz")
cell_feature_matrix_dir = os.path.join(xenium_output_data_dir, "cell_feature_matrix")
he_unregistered_image_path = os.path.join(he_dir, f"Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_he_image.ome.tif")
he_xenium_registration_landmarks_path = os.path.join(he_dir, f"Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_he_imagealignment.csv")
he_xenium_registration_landmarks_bigwarp_path = os.path.join(he_dir, "he_imagealignment_bigwarp.csv")
he_image_path = os.path.join(he_dir, "he_image_aligned.tif")
xenium_image_path = os.path.join(xenium_output_data_dir, "morphology.ome.tif")
SRA_accession_path = os.path.join(data_dir, "SRR_Acc_List_scrnaseq_crc_shortened.txt") if use_shortened_sra_accessions else os.path.join(data_dir, "SRR_Acc_List_scrnaseq_crc.txt")
idx_path = os.path.join(vk_ref_dir, "cosmic_cmc_index.idx")  #!!! change this for each run
t2g_path = os.path.join(vk_ref_dir, "cosmic_cmc_t2g.txt")  #!!! change this for each run

hovernet_dir = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "hover_net")
if not os.path.exists(hovernet_dir):
    raise ValueError(f"Please clone the Hover-Net repository to {hovernet_dir} before proceeding. See readme for details.")
hovernet_consep_checkpoint_tar = os.path.join(hovernet_dir, "hovernet_original_consep_notype_tf2pytorch.tar")
hovernet_environment_name = "hovernet_3090"  # hovernet, hovernet_3090

cell_feature_matrix_filtered_path = os.path.join(dir_output, "cell_gene_matrix_filtered.csv")
cell_type_path = os.path.join(dir_output, "celltype_filtered.csv")
cell_atlas_matrix_path = os.path.join(dir_output, "GSE132465_GEO_processed_CRC_10X_raw_UMI_count_matrix.txt.gz")
avg_expression_path = os.path.join(dir_output, "celltype_avgexp.csv")
avg_expression_cell_atlas_path = os.path.join(dir_output, "celltype_avgexp_cell_atlas.csv")

os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)
xenium_slice = patient_id_to_xenium_slice[patient_id]

# %% [markdown]
# ## Setup - Download data
#
# #### 1. Download the Xenium dataset

# %%
display(Image(filename="Table_1.png", width=400))

# %%
# %%time

patient_id_to_urls = {
    1: {
        "sra_accession_txt_shortened_url": None,
        "sra_accession_txt_full_url": None,
        "he_image_url": "https://caltech.box.com/shared/static/1bovlvqjd3eju1wjfxcdpe0cx5o18kz7.tif"
    },
    2: {
        "sra_accession_txt_shortened_url": None,
        "sra_accession_txt_full_url": None,
        "he_image_url": "https://caltech.box.com/shared/static/a89s2qqwbdup19bb0o5hojcgv97frej3.tif"
    },
    5: {
        "sra_accession_txt_shortened_url": "https://caltech.box.com/shared/static/0uq45k38dr7kcbl6eskr1gn0o3c0ea0l.txt",
        "sra_accession_txt_full_url": "https://caltech.box.com/shared/static/kdevjpq4r04gxwps5vmwccmba8rzy37n.txt",
        "he_image_url": "https://caltech.box.com/shared/static/v1urwb7mpk2dj67y8ugthpq5psbryj4p.tif"
    }
}

# H&E image and alignment file
# if not os.path.exists(he_unregistered_image_path):
#     !wget -O {he_unregistered_image_path} https://cf.10xgenomics.com/samples/xenium/2.0.0/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_he_image.ome.tif
# if not os.path.exists(he_xenium_registration_landmarks_path):  # custom landmarks: https://caltech.box.com/shared/static/g3blzv1770knq8qmsi1ok08w1w610gzq.csv
#     !wget -O {he_xenium_registration_landmarks_path} https://cf.10xgenomics.com/samples/xenium/2.0.0/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_he_imagealignment.csv

if not os.path.exists(he_image_path):
    # !wget -O {he_image_path} {patient_id_to_urls[patient_id]["he_image_url"]}

# Xenium files
if not os.path.exists(nucleus_boundaries_path):
    # !wget -O {xenium_output_data_dir}.zip https://cf.10xgenomics.com/samples/xenium/2.0.0/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs.zip
    # !unzip -d {xenium_output_data_dir} {xenium_output_data_dir}.zip

# varseek files
if patient_id == 5:
    if not os.path.exists(SRA_accession_path):
        sra_accession_txt_url = patient_id_to_urls[patient_id]["sra_accession_txt_shortened_url"] if use_shortened_sra_accessions else patient_id_to_urls[patient_id]["sra_accession_txt_full_url"]
        # !wget -O {SRA_accession_path} {sra_accession_txt_url}
    if not os.path.exists(idx_path):
        # !wget -O {idx_path} https://caltech.box.com/shared/static/f58qvvmp6en4dha28d7pakafg8j9jzqi.idx
    if not os.path.exists(t2g_path):
        # !wget -O {t2g_path} https://caltech.box.com/shared/static/taqo1cyswui69rdiy3jqpxdtsgbnin10.txt

# cell x gene matrix
if not os.path.exists(cell_feature_matrix_dir):
    if os.path.exists(f"{cell_feature_matrix_dir}.tar.gz"):
        with tarfile.open(f"{cell_feature_matrix_dir}.tar.gz", "r:gz") as tar:
            tar.extractall(path=xenium_output_data_dir)

# hovernet file
if not os.path.exists(hovernet_consep_checkpoint_tar):
    # !gdown 1BF0GIgNGYpfyqEyU0jMsA6MqcUpVQx0b -O {hovernet_consep_checkpoint_tar}

# cell atlas
if avg_exp_source == "cell_atlas" and not os.path.exists(cell_atlas_matrix_path):
    # https://explore.data.humancellatlas.org/projects/c715cd2f-dc7c-44a6-9cd5-b6a6d9f075ae
    # !curl -L -o {cell_atlas_matrix_path} 'https://humancellatlas.s3.amazonaws.com/file/deff856c7fe1d2c845af5b31e1c65a1dd95ea29541772a66c89bda3aaa8c0666.sha256?response-content-disposition=attachment%3Bfilename%3D%22GSE132465_GEO_processed_CRC_10X_raw_UMI_count_matrix.txt.gz%22&response-content-type=application%2Fgzip&AWSAccessKeyId=ASIAX4XVRZKHMMK7E7GB&Signature=%2BjJiYhKyw4FkieeGKMUtQtHo1lY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEAEaCXVzLWVhc3QtMSJGMEQCIG5Q8QB3usEZBRz4h8nSydmkH9zARk4YXjR80iJVwL41AiBTWB9KSbWMW82bOunlTJu2WYEAm3ORZMI5DFJv3Wr5WCr%2FAgia%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAIaDDU0Mjc1NDU4OTMyNiIM3i2SPpzqkkYeWOXhKtMCI3fNTLqPhAs7RvVWIonDdL55YV1Pbuujw0bH%2FjlK2hdHwl99tAV1QnLH%2BSen34PEKFe4gHMYM%2B05h8gremC%2BdPrupr11WSkqVnocDBokJS8ogxo57MsQ%2FRqP7BZcwPlMbj%2FqcrVjMNNuFIpwGx%2Bf16f7fYBgKItFtVTXLCid%2BWfk39EMnFGDFG5FJtwO%2Fh1E0OuWQEVULyI6kxpiRbo%2FE05sMtdGQLDktMUX7PPoekZxY0RhLxBmJ5r50VPAUERxgv8YtuB6Pe0a2YJurpx3f2bPKXnSvb9kTSHlgO5OJyn0BpjzUFewtjFUBJhUB2ARGvz1O%2BiTlwmEafVYC0jmLbY9WYdySwiL0CQG%2B6ATKMd4L3R5HsSguiB8ZJPOyfNUuwLqt8idubD7tDxmwVA6Fbsxde6Zmp7ruGp807tQkrw8FRw3JnHxrc3c0QoirOwMUYqQML3BkccGOp8BbdVEDGz0LM4DnSQT8vwIB%2FPy2LjggpScI55VicbiWwozhyApQrb0TyaevpeqVOVf26rMmTLC32wLj62OYtYrYbooeeLsDnQq%2BuyZU5sRoypno%2FW0swsBnJ36L1Ybv966rr3oOAcUmurhmIvt4BWXaaMAeHMwxHNS0sEhKpliWVLzYVxKJVdwJQ7WYn0DbFAUiHv8K9Qmfx6cOcVk3HRU&Expires=1759803471'
# Out:
# CPU times: user 0 ns, sys: 178 μs, total: 178 μs
# Wall time: 131 μs

# %% [markdown]
# The following files from the Xenium bundle are required:
# - nucleus boundaries: data_varseek/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs/nucleus_boundaries.csv.gz
# - cell_feature_matrix: data_varseek/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs/cell_feature_matrix/
# - H&E image: data_varseek/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs/he_data/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_he_image.ome.tif

# %%
# Change working directory
os.chdir(code_dir)

# %%
# if patient_id == 2 and not os.path.exists(he_image_path):
#     xenium_image_single_slice_path = xenium_image_path.replace(".ome.tif", f"_z{xenium_slice+1}.tif")

#     # OME-TIFFs have Z as the first axis here: (Z, Y, X) or (C, Z, Y, X)
#     with tifffile.TiffFile(xenium_image_path) as tif:
#         series = tif.series[0]          # main pyramid
#         zplane = series.asarray(key=xenium_slice)  # loads only one plane (full res)

#     # Save as plain single-plane TIFF (no OME XML)
#     tifffile.imwrite(xenium_image_single_slice_path, zplane, photometric="minisblack")
#     print("Saved:", xenium_image_single_slice_path, zplane.shape, zplane.dtype)

# %%
he_scale_down_factor = 2
xenium_scale_down_factor = 1

original_x_mvg, original_y_mvg, final_x_mvg, final_y_mvg, original_x_fix, original_y_fix, final_x_fix, final_y_fix = 1, 1, 1, 1, 1, 1, 1, 1

if he_scale_down_factor != 1 and os.path.exists(he_unregistered_image_path):
    he_original_dimension_dict, he_final_dimension_dict = determine_image_scale_factor(he_unregistered_image_path, scale = 1/he_scale_down_factor)
    original_x_mvg = he_original_dimension_dict["x"]
    original_y_mvg = he_original_dimension_dict["y"]
    final_x_mvg = he_final_dimension_dict["x"]
    final_y_mvg = he_final_dimension_dict["y"]

if xenium_scale_down_factor != 1 and os.path.exists(xenium_image_path):
    xenium_original_dimension_dict, xenium_final_dimension_dict = determine_image_scale_factor(xenium_image_path, scale = 1/xenium_scale_down_factor)
    print(f"Xenium original dimensions: {xenium_original_dimension_dict}")
    original_x_fix = xenium_original_dimension_dict["x"]
    original_y_fix = xenium_original_dimension_dict["y"]
    final_x_fix = xenium_final_dimension_dict["x"]
    final_y_fix = xenium_final_dimension_dict["y"]

for var in ["original_x_mvg", "original_y_mvg", "final_x_mvg", "final_y_mvg", "original_x_fix", "original_y_fix", "final_x_fix", "final_y_fix"]:
    print(f"{var} = {globals()[var]}")
# Out:
# original_x_mvg = 1
# original_y_mvg = 1
# final_x_mvg = 1
# final_y_mvg = 1
# original_x_fix = 1
# original_y_fix = 1
# final_x_fix = 1
# final_y_fix = 1

# %% [markdown]
# # Step 0
#
# Align H&E image to Xenium data

# %% [markdown]
# Convert 10x landmarks to bigwarp format: python varseek_notebooks/convert_landmarks_from_10x_to_bigwarp.py -i {he_xenium_registration_landmarks_path} -o {he_xenium_registration_landmarks_bigwarp_path}
#
# Scale landmarks according to image size changes: python varseek_notebooks/scale_landmarks.py --fp_in {he_xenium_registration_landmarks_bigwarp_path} --fp_out {he_xenium_registration_landmarks_bigwarp_path}_scaled.csv \
# --original_x_mvg {original_x_mvg} --original_y_mvg {original_y_mvg} --final_x_mvg {final_x_mvg} --final_y_mvg {final_y_mvg} \
# --original_x_fix {original_x_fix} --original_y_fix {original_y_fix} --final_x_fix {final_x_fix} --final_y_fix {final_y_fix}
#
# Use BigWarp to align the images (fixed=Xenium, moving=H&E)
# - Load in images to Fiji: H&E level {he_scale_down_factor}, Xenium level {xenium_scale_down_factor}
#   - H&E: {he_unregistered_image_path}
#   - Xenium: {xenium_image_path} (or {xenium_image_single_slice_path})
# - Select only slice 8 of the Xenium image (Image --> Hyperstacks --> Make Subset --> 8)
# - Ensure pixel spacing is 1 pixel
# - Import landmarks from {he_xenium_registration_landmarks_bigwarp_path} (or manually add landmarks)
# - Export moving image to: {he_image_split_path}
#
# Save RGB into a single image: python3 varseek_notebooks/save_transformed_image_as_single_file.py --input_fp {he_image_split_path} --output_fp {he_image_path} --slice_number 1 --num_channels 3

# %%
# === Load H&E ===
with tifffile.TiffFile(he_image_path) as tif:
    print("H&E series info:")
    he_axes = tif.series[0].axes  # (y,x,c)
    he_y_index, he_x_index, he_c_index = he_axes.index("Y"), he_axes.index("X"), he_axes.index("S")
    he_shape = tif.series[0].shape
    he_y, he_x = he_shape[he_y_index], he_shape[he_x_index]
    he_shape_2d = (he_y, he_x)
    he_dtype = tif.series[0].dtype
    print(f"  Series 0: shape={he_shape}, dtype={he_dtype}")

he_img = tifffile.imread(he_image_path)
if he_img.shape[0] == 3:   # (3, H, W)
    he_img = np.moveaxis(he_img, 0, -1)

# === Load Xenium morphology ===
with tifffile.TiffFile(xenium_image_path) as tif:
    print("\nXenium morphology series info:")
    xenium_axes = tif.series[0].axes  # (z,y,x)
    xenium_y_index, xenium_x_index, xenium_z_index = xenium_axes.index("Y"), xenium_axes.index("X"), xenium_axes.index("Z")
    xenium_shape = tif.series[0].shape
    xenium_y, xenium_x = xenium_shape[xenium_y_index], xenium_shape[xenium_x_index]
    xenium_shape_2d = (xenium_y, xenium_x)
    xenium_dtype = tif.series[0].dtype
    print(f"  Series 0: shape={xenium_shape}, dtype={xenium_dtype}")

xenium_img = tifffile.imread(xenium_image_path)
if xenium_slice is not None:
    xenium_img = xenium_img[xenium_slice]  # take one slice

if he_shape[he_c_index] != 3:
    print(f"Warning: H&E image has {he_shape[he_c_index]} channels, expected 3.")
if he_shape_2d != xenium_shape_2d:
    print(f"Warning: H&E shape {he_shape_2d} and Xenium morphology shape {xenium_shape_2d} do not match!")

# === Downsample both ===
scale = 0.05  # 5% size for visualization
he_small = cv2.resize(he_img, (0, 0), fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
xenium_small = cv2.resize(xenium_img, (0, 0), fx=scale, fy=scale, interpolation=cv2.INTER_AREA)

# === Normalize for display ===
he_small = cv2.normalize(he_small, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
xenium_small = cv2.normalize(xenium_small, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

if xenium_small.ndim == 2:
    xenium_small = cv2.cvtColor(xenium_small, cv2.COLOR_GRAY2BGR)

# === Plot side-by-side ===
fig, axs = plt.subplots(1, 2, figsize=(14, 7))
axs[0].imshow(he_small)
axs[0].set_title("Downsampled H&E")
axs[0].axis("off")

axs[1].imshow(xenium_small)
axs[1].set_title("Downsampled Xenium morphology")
axs[1].axis("off")

plt.tight_layout()
plt.show()

# === Overlay ===
overlay = cv2.addWeighted(he_small, 0.5, xenium_small, 0.5, 0)

plt.figure(figsize=(10, 10))
plt.imshow(overlay)
plt.axis("off")
plt.title("Overlay: H&E (50%) + Xenium morphology (50%)")
plt.show()
# Out:
# H&E series info:
#   Series 0: shape=(34224, 31395, 3), dtype=uint8
#
# Xenium morphology series info:
#   Series 0: shape=(13, 34224, 31395), dtype=uint16

# %% [markdown]
# ## Step 1
#
# Get the nuclei segmentation image for Xenium data. This step extracts from nuclei the boundaries file in the data bundle. May take a while.

# %%
command = f"""
python 1_get_xenium_nuclei_seg_image.py \
    --fp_boundaries {xenium_output_data_dir}/nucleus_boundaries.csv.gz \
    --dir_output {dir_output} \
    --fp_he_img {he_image_path} \
    --n_processes {n_processes}
"""
print(command)
# os.system(command)
# Out:
# python 1_get_xenium_nuclei_seg_image.py     --fp_boundaries /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/nucleus_boundaries.csv.gz     --dir_output /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2     --fp_he_img /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/he_data/he_image_aligned.tif     --n_processes 16

# %%
plot_downsampled(f"{dir_output}/xenium_nuclei.tif", downsample_factor=downsample_factor, title=f"Xenium Nuclei segmentation (downsampled {downsample_factor}×)")

# %% [markdown]
# ## Step 2
#
# Get the cell gene matrix for the Xenium data.

# %%
command = f"""
python 2_get_xenium_cell_gene_matrix.py \
    --dir_feature_matrix {xenium_output_data_dir}/cell_feature_matrix \
    --dir_output {dir_output}
"""
os.system(command)
# Out:
# Loading /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/cell_feature_matrix/barcodes.tsv
# Loading /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/cell_feature_matrix/features.tsv
# Saved /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2/cell_gene_matrix.csv
# Deleting intermediate files
# 0

# %% [markdown]
# ## Step 3.1
#
# (H&E nuclei segmentation) - divide the H&E image in to patches for nuclei segmentation.

# %%
command = f"""
python 3_segment_nuclei_he_image.py \
    --dir_output {dir_output} \
    --fp_he_img {he_image_path} \
    --dir_hovernet {hovernet_dir} \
    --gpu_id {gpu_id} \
    --step 1
"""
os.system(command)
# Out:
# python 3_segment_nuclei_he_image.py     --dir_output /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2     --fp_he_img /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/he_data/he_image_aligned.tif     --dir_hovernet /mnt/gpussd2/jrich/Desktop/hover_net     --gpu_id 0     --step 1

# %% [markdown]
# ## Step 3.2
#
# (H&E nuclei segmentation) - segment the nuclei using Hover-Net. May take a while.
#
# During this step, we have encountered the error below, though the segmentation still ran fine:
# ``Error: mkl-service + Intel(R) MKL: MKL_THREADING_LAYER=INTEL is incompatible with libgomp.so.1 library. Try to import numpy first or set the threading layer accordingly. Set MKL_SERVICE_FORCE_INTEL to force it.``

# %%
conda_base = subprocess.check_output("conda info --base", shell=True).decode().strip()

cmd = f"""
source {conda_base}/etc/profile.d/conda.sh && \
conda activate {hovernet_environment_name} && \
python 3_segment_nuclei_he_image.py \
  --dir_output {dir_output} \
  --fp_he_img {he_image_path} \
  --dir_hovernet {hovernet_dir} \
  --gpu_id {gpu_id} \
  --step 2
"""

try:
  # subprocess.run(cmd, shell=True, executable="/bin/bash", check=True)
  raise subprocess.CalledProcessError(1, "placeholder")
except subprocess.CalledProcessError as e:
  print(f"Error during execution: {e}")
  print(f"Please open up a terminal in the `GHIST/data_processing` folder and run:")
  print(f"conda activate {hovernet_environment_name}")
  print(f"python {code_dir}/3_segment_nuclei_he_image.py --dir_output {dir_output} --fp_he_img {he_image_path} --dir_hovernet {hovernet_dir} --gpu_id {gpu_id} --step 2")
# Out:
# Error during execution: Command 'placeholder' returned non-zero exit status 1.
# Please open up a terminal in the `GHIST/data_processing` folder and run:
# conda activate hovernet_3090
# python /mnt/gpussd2/jrich/Desktop/GHIST/data_processing/3_segment_nuclei_he_image.py --dir_output /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2 --fp_he_img /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/he_data/he_image_aligned.tif --dir_hovernet /mnt/gpussd2/jrich/Desktop/hover_net --gpu_id 0 --step 2

# %% [markdown]
# ## Step 3.3
#
# (H&E nuclei segmentation) - combine the nuclei from patches to a whole image.

# %%
conda_base = subprocess.check_output("conda info --base", shell=True).decode().strip()

cmd = f"""
source {conda_base}/etc/profile.d/conda.sh && \
conda activate ghist && \
python 3_segment_nuclei_he_image.py \
  --dir_output {dir_output} \
  --fp_he_img {he_image_path} \
  --dir_hovernet {hovernet_dir} \
  --gpu_id {gpu_id} \
  --step 3
"""

try:
  # subprocess.run(cmd, shell=True, executable=f"/bin/bash", check=True)
  raise subprocess.CalledProcessError(1, "placeholder")
except subprocess.CalledProcessError as e:
  print(f"Error during execution: {e}")
  print(f"Please open up a terminal in the `GHIST/data_processing` folder and run:")
  print(f"conda activate ghist")
  print(f"python {code_dir}/3_segment_nuclei_he_image.py --dir_output {dir_output} --fp_he_img {he_image_path} --dir_hovernet {hovernet_dir} --gpu_id {gpu_id} --step 3")
# Out:
# Error during execution: Command 'placeholder' returned non-zero exit status 1.
# Please open up a terminal in the `GHIST/data_processing` folder and run:
# conda activate ghist
# python /mnt/gpussd2/jrich/Desktop/GHIST/data_processing/3_segment_nuclei_he_image.py --dir_output /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2 --fp_he_img /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/he_data/he_image_aligned.tif --dir_hovernet /mnt/gpussd2/jrich/Desktop/hover_net --gpu_id 0 --step 3

# %%
for filename in ["he_image_nuclei_seg.tif", "he_image_nuclei_seg_microns.tif"]:
    plot_downsampled(f"{dir_output}/{filename}", downsample_factor=downsample_factor, title=f"H&E Nuclei segmentation, {filename}")

# %% [markdown]
# ## Step 4
#
# Determine corresponding cells between H&E images and Xenium data. May take a while.

# %%
command = f"""
python 4_get_corresponding_cells.py \
    --dir_output {dir_output} \
    --n_processes {n_processes}
"""  # --min_overlap_fraction 0.1 \
print(command)
# os.system(command)
# Out:
# python 4_get_corresponding_cells.py     --dir_output /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2     --n_processes 16

# %%
# !wc -l {dir_output}/cell_gene_matrix.csv
# !wc -l {dir_output}/cell_gene_matrix_filtered.csv

# !wc -l {dir_output}/matched_nuclei.csv
# !wc -l {dir_output}/matched_nuclei_filtered.csv
# Out:
# 326947 /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2/cell_gene_matrix.csv
# 137236 /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2/cell_gene_matrix_filtered.csv
# 163020 /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2/matched_nuclei.csv
# 137236 /mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output_p2/matched_nuclei_filtered.csv

# %% [markdown]
# 📌 At this point the following files should in the directory ``dir_output``:
#
# - ``cell_gene_matrix.csv`` - cell gene matrix for all cells in the Xenium data
# - *``cell_gene_matrix_filtered.csv`` - cell gene matrix only for filtered cells
# - ``genes.txt`` - list of genes in the panel
# - *``he_image_nuclei_seg.tif`` - nuclei segmented from the H&E image
# - ``he_image_nuclei_seg_microns.tif`` - nuclei segmented from the H&E image resized to 1 pixel = 1 micron
# - ``matched_nuclei.csv`` - corresponding cell IDs between H&E and Xenium
# - *``matched_nuclei_filtered.csv`` - corresponding cell IDs of filtered cells
# - ``xenium_cell_ids_dict.csv`` - created only if Xenium cell IDs are strings
# - ``xenium_nuclei.tif`` - nuclei segmented from Xenium data
#
# (*) marks files needed to run GHIST (see ``data_demo`` as an example)

# %% [markdown]
# ## Optional - Cell type
#
# Cell type annotation - if you want to use cell type or neighbourhood information, run your preferred cell annotation method on ``cell_gene_matrix_filtered.csv`` to get cell type labels. Then create a csv file with columns like the following (e.g., see ``data_demo/celltype_filtered.csv``):
#
# ```
# c_id,ct
# 1,T
# 2,Malignant
# 3,Macrophage
# ...etc
# ```
#
# Number of cell types: based on our experiments we recommend using <10 cell types
#
# 📌 If you do not wish to use cell type information, in your config file:
#
# - ``"celltype": false,``
# - delete parameter `fp_cell_type`

# %%
models.download_models(force_update = True)

# %%
# models.models_description()

# %%
model_pkl = "Human_Colorectal_Cancer.pkl"
model = models.Model.load(model = model_pkl)

# print cell types as a list to copy-paste into config files
print("[{}]".format(", ".join(f'"{x}"' for x in list(model.cell_types))))  # extra-complicated to use double quotes instead of single
# Out:
# ["CD19+CD20+ B", "CD4+ T cells", "CD8+ T cells", "CMS1", "CMS2", "CMS3", "CMS4", "Enteric glial cells", "Goblet cells", "IgA+ Plasma", "IgG+ Plasma", "Intermediate", "Lymphatic ECs", "Mast cells", "Mature Enterocytes type 1", "Mature Enterocytes type 2", "Myofibroblasts", "NK cells", "Pericytes", "Pro-inflammatory", "Proliferating", "Proliferative ECs", "Regulatory T cells", "SPP1+", "Smooth muscle cells", "Stalk-like ECs", "Stem-like/TA", "Stromal 1", "Stromal 2", "Stromal 3", "T follicular helper cells", "T helper 17 cells", "Tip-like ECs", "Unknown", "cDC", "gamma delta T cells"]

# %% [markdown]
# ### Copy and paste the list into config

# %%
# import pandas as pd
# import scanpy as sc
# filtered_cell_df = pd.read_csv(cell_feature_matrix_filtered_path, index_col=0)
# filtered_ids = set(filtered_cell_df.index.tolist())

# cell_barcode_to_id_df = pd.read_csv("/mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/output/xenium_cell_ids_dict.csv", index_col=0)
# cell_barcode_to_id_df.index.name = "barcode"
# id_to_barcode = {v: k for k, v in cell_barcode_to_id_df["cell_id_num"].to_dict().items()}

# filtered_barcodes = [id_to_barcode[cell_id] for cell_id in filtered_ids if cell_id in id_to_barcode]

# adata = sc.read_10x_mtx("/mnt/gpussd2/jrich/Desktop/GHIST/data_varseek/Xenium_V1_Human_Colon_Cancer_P{patient_id}_CRC_Add_on_FFPE_outs/cell_feature_matrix", var_names='gene_symbols', cache=True)
# adata = adata[adata.obs.index.isin(filtered_barcodes)].copy()
# sc.pp.normalize_total(adata, target_sum=1e4)  # Normalize counts per
# sc.pp.log1p(adata)  # Log-transform the data
# adata

# %%
cell_matrix_filtered_df = pd.read_csv(cell_feature_matrix_filtered_path, index_col=0)
adata = ad.AnnData(cell_matrix_filtered_df)
sc.pp.normalize_total(adata, target_sum=1e4)  # Normalize counts per
sc.pp.log1p(adata)  # Log-transform the data

predictions = celltypist.annotate(adata, model=model_pkl, majority_voting=True)

df_out = predictions.predicted_labels[['majority_voting']].copy()
df_out = df_out.reset_index()
df_out = df_out.rename(columns={'index': 'c_id', 'majority_voting': 'ct'})
df_out.to_csv(cell_type_path, index=False)

print(df_out['ct'].value_counts())
# Out:
# 🔬 Input data has 137235 cells and 422 genes
# 🔗 Matching reference genes in the model
# 🧬 351 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 25
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# CMS2                         77178
# Myofibroblasts               16036
# CD4+ T cells                 13180
# IgG+ Plasma                   6674
# CD8+ T cells                  5854
# Mature Enterocytes type 2     5351
# CMS3                          4578
# T helper 17 cells             2912
# CD19+CD20+ B                  1777
# SPP1+                         1457
# Regulatory T cells             929
# Mast cells                     617
# Tip-like ECs                   289
# CMS1                           217
# Unknown                        186
# Name: ct, dtype: int64

# %% [markdown]
# ## Optional - AvgExp
#
# Averaged single cell gene expression profiles of cell types - this is an optional input. These profiles do not need to be matched for the same sample of interest, but should ideally be for the same tissue type (e.g. breast cancer). AvgExp can have a flexible number and categories of cell types from a single or multiple reference datasets. The same AvgExp data should be used during training and inference.
#
# 📌 If you do not wish to use AvgExp, in your config file:
#
# - ``"avgexp": false,``
# - delete parameter `fp_avgexp`

# %%
if avg_exp_source == "data":
    save_avg_expression(adata, df_out, avg_expression_path)

elif avg_exp_source == "cell_atlas":
    adata_cell_atlas = sc.read_csv(cell_atlas_matrix_path, delimiter='\t', first_column_names=True).transpose()

    with open(os.path.join(dir_output, "genes.txt")) as f:
        genes = set(line.strip() for line in f if line.strip())

    adata_cell_atlas = adata_cell_atlas[:, adata_cell_atlas.var_names.isin(genes)].copy()

    # Check retention ratio
    retained_ratio = adata_cell_atlas.shape[1] / len(genes)
    if retained_ratio < 0.9:
        raise ValueError(f"Only {retained_ratio:.1%} of genes retained (<90%).")
    else:
        print(f"{retained_ratio:.1%} of genes retained (>=90%). Filling missing genes with 0s.")
    
    # Add missing genes as zero columns
    missing_genes = [g for g in genes if g not in adata_cell_atlas.var_names]
    if missing_genes:
        zero_data = sparse.csr_matrix((adata_cell_atlas.n_obs, len(missing_genes))) if sparse.issparse(adata_cell_atlas.X) else np.zeros((adata_cell_atlas.n_obs, len(missing_genes)), dtype=adata_cell_atlas.X.dtype)
        adata_missing = sc.AnnData(X=zero_data, var=pd.DataFrame(index=missing_genes))
        adata_cell_atlas = ad.concat([adata_cell_atlas, adata_missing], axis=1, join='outer', fill_value=0)

    sc.pp.normalize_total(adata_cell_atlas, target_sum=1e4)  # Normalize counts per
    sc.pp.log1p(adata_cell_atlas)  # Log-transform the data

    predictions_cell_atlas = celltypist.annotate(adata_cell_atlas, model=model_pkl, majority_voting=True)
    df_out_adata_cell_atlas = predictions_cell_atlas.predicted_labels[['majority_voting']].copy()
    df_out_adata_cell_atlas = df_out_adata_cell_atlas.reset_index()
    df_out_adata_cell_atlas = df_out_adata_cell_atlas.rename(columns={'index': 'c_id', 'majority_voting': 'ct'})
    
    save_avg_expression(adata_cell_atlas, df_out_adata_cell_atlas, avg_expression_cell_atlas_path)
# Out:
# 97.6% of genes retained (>=90%). Filling missing genes with 0s.
# ⚠️ Warning: invalid expression matrix, expect ALL genes and log1p normalized expression to 10000 counts per cell. The prediction result may not be accurate
# 🔬 Input data has 127378 cells and 422 genes
# 🔗 Matching reference genes in the model
# 🧬 351 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 25
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %% [markdown]
# # New territory

# %% [markdown]
# ## Step 5

# %% [markdown]
# Create variant data with varseek

# %%
if patient_id != 5:
    print("Skipping variant analysis for patient_id != 5")
    sys.exit(0)

# %%
dry_run = True

with open(SRA_accession_path) as f:
    srr_list = f.read().split()

fastq_list = []
for srr in srr_list:
    fastq_list.append(os.path.join(sequencing_data_raw_dir, f"{srr}_1.fastq"))
    fastq_list.append(os.path.join(sequencing_data_raw_dir, f"{srr}_2.fastq"))
fastqs = " ".join(fastq_list)

if not any(os.path.exists(fastq) for fastq in fastq_list):
    os.makedirs(sequencing_data_raw_dir, exist_ok=True)
    os.chdir(sequencing_data_raw_dir)

    # check for fastqs
    try:
        print("Downloading fastq files")
        
        print("Running prefetch")
        prefetch_command = ["prefetch", "--progress", "--verbose"] + srr_list
        print(" ".join(prefetch_command))
        if not dry_run:
            subprocess.run(prefetch_command, check=True)
        
        print("Downloading files")
        data_download_command = ["fasterq-dump", "--outdir", os.path.abspath(sequencing_data_raw_dir), "--threads", str(n_processes), "--progress", "--verbose", "--split-files"] + srr_list
        print(" ".join(data_download_command))
        if not dry_run:
            subprocess.run(data_download_command, check=True)
        
        print(f"Fastq data downloaded successfully to {sequencing_data_raw_dir}")
    except Exception as e:
        print(f"Error running fasterq-dump: {e}")
        raise  # re-raises the original exception
    os.chdir(code_dir)

# %%
technology = "10XV3"
k = 41  #* don't change unless I change my vk ref index settings
min_counts = 3
use_binary_matrix = True
drop_empty_columns = True

command = f"""
python 5_get_variant_data.py \
    --fastqs {fastqs} \
    --dir_output {dir_output} \
    --technology {technology} \
    --k {k} \
    --min_counts {min_counts} \
    {"--disable_use_binary_matrix" if not use_binary_matrix else ""} \
    {"--disable_drop_empty_columns" if not drop_empty_columns else ""} \
    --n_processes {n_processes} \
    --vk_ref_dir {vk_ref_dir} \
    --vk_count_dir {vk_count_dir} \
    --index {idx_path} \
    --t2g {t2g_path}
"""
print(command)
# os.system(command)
